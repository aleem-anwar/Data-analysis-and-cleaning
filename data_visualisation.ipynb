# %%
import matplotlib.pyplot as plt
import pandas as pd 
import numpy as np

# %%
x = np.linspace(0,5,10)
x
y = x**2
y
# Out:
# array([ 0.        ,  0.30864198,  1.2345679 ,  2.77777778,  4.9382716 ,
#         7.71604938, 11.11111111, 15.12345679, 19.75308642, 25.        ])

# %%
plt.plot(x,y)
plt.title("Graph")
plt.xlabel("X-axis")
plt.ylabel("Y-axis")
# Out:
# Text(0, 0.5, 'Y-axis')

# %%
plt.subplot(2,2,1)
plt.plot(x,y)
plt.subplot(2,2,2)
plt.plot(y,x)
plt.subplot(2,2,3)
plt.plot(y**2,x) 
plt.subplot(2,2,4) 
plt.plot(x**2,y)

# %%
canv = plt.figure(dpi = 1800)
a1 = canv.add_axes([0.1,0.1,0.8,0.8])
a1.plot(x,y)
plt.title('X v/s Y graph')
plt.xlabel("X axis")
plt.ylabel("Y axis")
a2 = canv.add_axes([0.25,0.5,0.3,0.3])
a2.plot(x**3,y)
plt.title("X^3 V/S Y graph")
plt.xlabel("X axis") 
plt.ylabel("Y axis")
# Out:
# Text(0, 0.5, 'Y axis')

# %%
import seaborn as sns

# %%
df = sns.load_dataset('tips')
df
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
df['size'].unique()
# Out:
# array([2, 3, 4, 1, 6, 5])

# %%
sns.displot(df['total_bill'], kde = True, bins = 15)

# %%
plt.subplot(1,2,1)
sns.histplot(df['total_bill'], kde = True, bins = 15) 
plt.subplot(1,2,2) 
sns.histplot(df['tip'], kde = True, bins = 15)
# Out:
# <Axes: xlabel='tip', ylabel='Count'>

# %%
sns.jointplot(x = 'tip',y= 'total_bill',data = df)

# %%
sns.jointplot(x = 'tip',y= 'total_bill',data = df,kind='kde')

# %%
sns.jointplot(x = 'tip',y= 'total_bill',data = df,kind='hex')

# %%
sns.jointplot(x = 'tip',y= 'total_bill',data = df,kind='reg')

# %%
sns.pairplot(df,hue='sex')

# %%
sns.countplot(x =df['sex'],hue=df['smoker'])
# Out:
# <Axes: xlabel='sex', ylabel='count'>

# %%
sns.barplot(x=df['sex'],y=df['tip'])
# Out:
# <Axes: xlabel='sex', ylabel='tip'>

# %%
import numpy as np
sns.barplot(x=df['sex'],y=df['tip'],estimator=np.max)
# Out:
# <Axes: xlabel='sex', ylabel='tip'>

# %%
sns.boxplot(x = 'tip',y = 'day', data=df)
# Out:
# <Axes: xlabel='tip', ylabel='day'>

# %%
sns.violinplot(x = 'day', y = 'total_bill', data=df)
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
sns.stripplot(x='day',y='total_bill',data=df)
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
sns.swarmplot(x='day',y='total_bill',data=df)
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>
